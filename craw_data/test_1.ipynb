# %%
import pandas as pd
import numpy as np

# %%
data_1 = pd.read_csv('F:/NCKH/craw_data/data/cong_nghe/shop_Camera_Toan_Cau.csv')
data_2 = pd.read_csv('F:/NCKH/craw_data/data/cong_nghe/shop_EZVIZ_VN_Authorized_Store.csv')
data_3 = pd.read_csv('F:/NCKH/craw_data/data/cong_nghe/shop_Zentino.csv')

# %%
data_1
# Out:
#                                                 Review  Rating            Date
# 0                                                  NaN       1   18 thg 8 2020
# 1                                                  NaN       1   21 thg 9 2020
# 2                                                  NaN       1  13 thg 11 2020
# 3                                        hàng ok lắm         1  29 thg 12 2023
# 4                                                  NaN       1  19 thg 10 2021
# ..                                                 ...     ...             ...
# 995                                                NaN       5   26 thg 9 2020
# 996  Chất lượng camera dỏm, hình delay, khi nhấn qu...       5   20 thg 8 2023
# 997  quá ngon luôn. tốt trong tầm giá. cảm biến chu...       5  04 thg 12 2020
# 998                 Khi nhấn vô nói rè và ồ kinh khủng       5   21 thg 5 2021
# 999                                                NaN       5   28 thg 8 2020
#
# [1000 rows x 3 columns]

# %%
data_2
# Out:
#                                                 Review  Rating           Date
# 0                                                  NaN       1  26 thg 4 2024
# 1                                                  NaN       3  17 thg 6 2024
# 2                                                  NaN       3  16 thg 1 2024
# 3    Giám sát trong nhà đáng tin cậy, Kết nối mượt ...       3  17 thg 9 2024
# 4    sản phẩm như mô tả. giao hàng nhanh giá cả hợp...       3  18 thg 8 2024
# ..                                                 ...     ...            ...
# 993                                                NaN       5  18 thg 7 2024
# 994          Kết nối:ok\n Giá Cả:ok\n Độ phân giải:ok        5  22 thg 6 2024
# 995                                                NaN       5  23 thg 7 2024
# 996                                                NaN       5  11 thg 7 2024
# 997  Âm thanh hai chiều tiện lợi, Thiết kế chắc chắ...       5  15 thg 7 2024
#
# [998 rows x 3 columns]

# %%
data_3
# Out:
#                                                 Review  Rating            Date
# 0                                          ok.hang dep       1  28 thg 12 2022
# 1                                                  NaN       1   22 thg 1 2022
# 2    Đã mua rất nhiều lần từ shop này, để đấy không...       1   18 thg 7 2023
# 3                                                  NaN       1  15 thg 11 2023
# 4                                                  NaN       1   11 thg 1 2022
# ..                                                 ...     ...             ...
# 580  Cho 2 ngày xử lý mà không giải quyết đc tồn đọ...       5   26 thg 4 2022
# 581                                                NaN       5    4 ngày trước
# 582  Máy ko nhận thẻ nhớ...thằng kinh doanh nói 1 đ...       5   26 thg 4 2022
# 583  Thẻ lỗi kêu bh cứ lòng vòng..làm ăn như ship\n...       5  06 thg 10 2021
# 584  Camara như cái đầu buồi. Những cái đoạn mất đồ...       5   06 thg 5 2022
#
# [585 rows x 3 columns]

# %%
data_1 = pd.read_csv('F:/NCKH/craw_data/data/cong_nghe/shop_Camera_Toan_Cau.csv',encoding='utf-8')

# %%
fix_data_1 = data_1.dropna()

# %%
#kiểm tra giá trị NaN
fix_data_1.isna().sum()
# Out:
# Review    0
# Rating    0
# Date      0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import Tfifix_data_1Vectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 7
#       5 from nltk.corpus import stopwords
#       6 from nltk.stem import PorterStemmer
# ----> 7 from sklearn.feature_extraction.text import Tfifix_data_1Vectorizer
#       8 from sklearn.naive_bayes import MultinomialNB
#       9 from sklearn.model_selection import train_test_split
#
# ImportError: cannot import name 'Tfifix_data_1Vectorizer' from 'sklearn.feature_extraction.text' (c:\Users\ADMIN\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_extraction\text.py)

# %%
# Hàm tiền xử lý văn bản 
def preprocess(text):
    if isinstance(text, str):  # Kiểm tra nếu text là chuỗi
        
        # Chuyển về chữ thường
        text = text.lower()
        
        # Chỉ giữ lại chữ cái, chữ số và dấu tiếng Việt
        text = re.sub(r'[^\w\sàáảãạâầấẩẫậăằắẳẵặèéẻẽẹêềếểễệìíỉĩịòóỏõọôồốổỗộơờớởỡợùúủũụưừứửữựỳýỷỹỵđĐ]', ' ', text)
        
        # Loại bỏ khoảng trắng thừa
        text = re.sub(r'\s+', ' ', text).strip()
        
        # Loại bỏ ký tự xuống dòng
        text = text.replace('\n', ' ').replace('\r', ' ')
        
        return text
    else:
        return ""

# Áp dụng tiền xử lý cho cột "Review"
fix_data_1['Review'] = fix_data_1['Review'].apply(preprocess)

# Xem dữ liệu sau khi xử lý
print(fix_data_1)
# Out:
#                                                 Review  Rating            Date
# 3                                          hàng ok lắm       1  29 thg 12 2023
# 6       phù hợp cho cả sử dụng trong nhà và ngoài trời       2   09 thg 9 2024
# 7                                       ok với tầm giá       2   18 thg 1 2024
# 8                          hàng chất lượng cảm ơn shòp       2  13 thg 12 2023
# 10                                                 tốt       3   09 thg 7 2020
# ..                                                 ...     ...             ...
# 991  đặt hàng có thẻ nhớ mà nhận lại không có hàng ...       5   01 thg 9 2020
# 992  mua ba cái thì 1 cái bị lỗi không xoay được 36...       5  06 thg 11 2020
# 996  chất lượng camera dỏm hình delay khi nhấn quay...       5   20 thg 8 2023
# 997  quá ngon luôn tốt trong tầm giá cảm biến chuyể...       5  04 thg 12 2020
# 998                 khi nhấn vô nói rè và ồ kinh khủng       5   21 thg 5 2021
#
# [500 rows x 3 columns]
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import pipeline

# Tải mô hình và tokenizer
model_name = '5CD-AI/Vietnamese-Sentiment-visobert'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# Tạo pipeline phân tích cảm xúc
sentiment_pipeline = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python39\lib\site-packages\huggingface_hub\utils\_http.py:406, in hf_raise_for_status(response, endpoint_name)
#     405 try:
# --> 406     response.raise_for_status()
#     407 except HTTPError as e:
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/vitextemotion/resolve/main/tokenizer_config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import pipeline


# Tải mô hình và tokenizer
model_name = '5CD-AI/Vietnamese-Sentiment-visobert'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# Tạo pipeline phân tích cảm xúc
sentiment_pipeline = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# Hàm phân tích cảm xúc
def analyze_sentiment(Review):
    try:
        result = sentiment_pipeline(Review)
        # Lấy nhãn cảm xúc từ kết quả
        label = result[0]['label']
        return label
    except Exception as e:
        return "error"  # Trả về "error" nếu có lỗi

# Phân tích cảm xúc cho từng dòng trong cột 'comment'
fix_data_1['sentiment'] = fix_data_1['comment'].apply(analyze_sentiment)

# Phân loại thành 3 nhóm
df_positive = fix_data_1[fix_data_1['sentiment'] == 'positive']
df_negative = fix_data_1[fix_data_1['sentiment'] == 'negative']
df_neutral = fix_data_1[fix_data_1['sentiment'] == 'neutral']

# Lưu kết quả vào file mới
# df.to_csv("comments_with_sentiment.csv", index=False)
# print("Kết quả đã được lưu vào file 'comments_with_sentiment.csv'")

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import pandas as pd

# Load tokenizer và model PhoBERT
tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base", use_fast=False)
phobert = AutoModel.from_pretrained("vinai/phobert-base")

# Lớp phân loại cảm xúc (kết hợp PhoBERT)
class PhoBERTSentimentClassifier(nn.Module):
    def __init__(self, phobert):
        super(PhoBERTSentimentClassifier, self).__init__()
        self.phobert = phobert
        self.dropout = nn.Dropout(0.3)
        self.fc = nn.Linear(768, 3)  # 3 nhãn: tiêu cực, trung tính, tích cực

    def forward(self, input_ids, attention_mask):
        outputs = self.phobert(input_ids=input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]  # Lấy embedding của token [CLS]
        cls_output = self.dropout(cls_output)
        logits = self.fc(cls_output)
        return logits

# Khởi tạo mô hình
model = PhoBERTSentimentClassifier(phobert)


fix_data_1['Review'] = fix_data_1['Review'].apply(preprocess)

# Gán nhãn cảm xúc (giả sử dữ liệu đã gán nhãn sẵn)
label_mapping = {'tiêu cực': 0, 'trung tính': 1, 'tích cực': 2}
fix_data_1['Sentiment'] = fix_data_1['Sentiment'].map(label_mapping)

# Tách dữ liệu
X_train, X_test, y_train, y_test = train_test_split(
    fix_data_1['Review'], fix_data_1['Sentiment'], test_size=0.2, random_state=42
)

# Tokenizer dữ liệu
def encode_data(text_list, tokenizer, max_length=256):
    return tokenizer(
        list(text_list),
        padding=True,
        truncation=True,
        max_length=max_length,
        return_tensors="pt"
    )

train_encodings = encode_data(X_train, tokenizer)
test_encodings = encode_data(X_test, tokenizer)

# Dataloader
train_data = torch.utils.data.TensorDataset(
    train_encodings['input_ids'], train_encodings['attention_mask'], torch.tensor(y_train.values)
)
test_data = torch.utils.data.TensorDataset(
    test_encodings['input_ids'], test_encodings['attention_mask'], torch.tensor(y_test.values)
)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=16, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=16, shuffle=False)

# Huấn luyện mô hình
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=2e-5)
loss_fn = nn.CrossEntropyLoss()

# Vòng lặp huấn luyện
for epoch in range(3):
    model.train()
    total_loss = 0
    for batch in train_loader:
        input_ids, attention_mask, labels = [x.to(device) for x in batch]
        optimizer.zero_grad()
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f"Epoch {epoch+1}, Loss: {total_loss}")

# Đánh giá mô hình
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for batch in test_loader:
        input_ids, attention_mask, labels = [x.to(device) for x in batch]
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        preds = torch.argmax(outputs, dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

print(classification_report(all_labels, all_preds, target_names=['tiêu cực', 'trung tính', 'tích cực']))
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...
