# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException,ElementClickInterceptedException,StaleElementReferenceException
from selenium.webdriver.common.by import By
from time import sleep
import pandas as pd

# %%
#EZVIZ VN Authorized Store
driver = webdriver.Chrome()
driver.get("https://www.lazada.vn/products/lazmall-camera-ip-wifi-ezviz-c6n-1080p-20mp-cs-c6n-smart-ir-quan-sat-ban-dem-10m-trong-nha-dam-thoai-2-chieu-theo-doi-chuyen-dong-thong-minh-hang-chinh-hang-ezviz-bao-hanh-2-nam-ezviz-hoang-nguyen-mall-i1430483342-s5920975890.html?c=&channelLpJumpArgs=&clickTrackInfo=query%253Acamera%252Bezviz%252Bc6n%253Bnid%253A1430483342%253Bsrc%253ALazadaMainSrp%253Brn%253Ae171c0cdb647cb3476e3b4d89c397073%253Bregion%253Avn%253Bsku%253A1430483342_VNAMZ%253Bprice%253A439000%253Bclient%253Adesktop%253Bsupplier_id%253A200166942087%253Bbiz_source%253Ahttps%253A%252F%252Fwww.lazada.vn%252F%253Bslot%253A1%253Butlog_bucket_id%253A470687%253Basc_category_id%253A15212%253Bitem_id%253A1430483342%253Bsku_id%253A5920975890%253Bshop_id%253A2047908%253BtemplateInfo%253A107883_A3_C_D_E%25231103_B_L%2523&freeshipping=1&fs_ab=2&fuse_fs=&lang=en&location=Vietnam&price=4.39E%205&priceCompare=skuId%3A5920975890%3Bsource%3Alazada-search-voucher%3Bsn%3Ae171c0cdb647cb3476e3b4d89c397073%3BunionTrace%3A9c3b889b17306780625491862e%3BoriginPrice%3A439000%3BvoucherPrice%3A439000%3BdisplayPrice%3A439000%3BsinglePromotionId%3A-1%3BsingleToolCode%3AmockedSalePrice%3BvoucherPricePlugin%3A1%3BbuyerId%3A0%3Btimestamp%3A1730678062934&ratingscore=4.9661190965092405&request_id=e171c0cdb647cb3476e3b4d89c397073&review=974&sale=3174&search=1&source=search&spm=a2o4n.searchlist.list.1&stock=1")
# Out:
# Error sending stats to Plausible: error sending request for url (https://plausible.io/api/event)
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[2], line 3
#       1 #EZVIZ VN Authorized Store
#       2 driver = webdriver.Chrome()
# ...

# %%
#Zentino
driver = webdriver.Chrome()
driver.get("https://www.lazada.vn/products/camera-wifi-thong-minh-ezviz-c6n-do-phan-giai-2mp-1080p-i1448998338-s8254610982.html?c=&channelLpJumpArgs=&clickTrackInfo=query%253Acamera%252Bezviz%252Bc6n%253Bnid%253A1448998338%253Bsrc%253ALazadaMainSrp%253Brn%253Ae171c0cdb647cb3476e3b4d89c397073%253Bregion%253Avn%253Bsku%253A1448998338_VNAMZ%253Bprice%253A347000%253Bclient%253Adesktop%253Bsupplier_id%253A200158077976%253Bbiz_source%253Ahttps%253A%252F%252Fwww.lazada.vn%252F%253Bslot%253A0%253Butlog_bucket_id%253A470687%253Basc_category_id%253A15212%253Bitem_id%253A1448998338%253Bsku_id%253A8254610982%253Bshop_id%253A796440%253BtemplateInfo%253A107883_C_D_E%2523-1_A3%25231103_B_L%2523&freeshipping=1&fs_ab=2&fuse_fs=&lang=en&location=Vietnam&price=3.47E%205&priceCompare=skuId%3A8254610982%3Bsource%3Alazada-search-voucher%3Bsn%3Ae171c0cdb647cb3476e3b4d89c397073%3BunionTrace%3A9c3b889b17306780625491862e%3BoriginPrice%3A347000%3BvoucherPrice%3A347000%3BdisplayPrice%3A347000%3BsinglePromotionId%3A-1%3BsingleToolCode%3A-1%3BvoucherPricePlugin%3A1%3BbuyerId%3A0%3Btimestamp%3A1730678062934&ratingscore=4.93526405451448&request_id=e171c0cdb647cb3476e3b4d89c397073&review=587&sale=2993&search=1&source=search&spm=a2o4n.searchlist.list.0&stock=1")

# %%
#Camera Toàn Cầu
driver = webdriver.Chrome()
driver.get("https://www.lazada.vn/products/camera-wifi-ezviz-c6n-2mp-c6n-pro-2k-3mp-xoay-360-thong-minh-dam-thoai-2-chieu-quay-theo-chuyen-dong-camera-cs-c6n-giam-sat-wifi-khong-day-i337146881-s5180394996.html?c=&channelLpJumpArgs=&clickTrackInfo=query%253Acamera%252Bezviz%252Bc6n%253Bnid%253A337146881%253Bsrc%253ALazadaMainSrp%253Brn%253A0230bec5a85024148e0d6506ba1454fc%253Bregion%253Avn%253Bsku%253A337146881_VNAMZ%253Bprice%253A397000%253Bclient%253Adesktop%253Bsupplier_id%253A100250345%253Bbiz_source%253Ah5_hp%253Bslot%253A5%253Butlog_bucket_id%253A470687%253Basc_category_id%253A15212%253Bitem_id%253A337146881%253Bsku_id%253A5180394996%253Bshop_id%253A259877%253BtemplateInfo%253A107883_C_D_E%25231103_B_L%2523-1_A3%2523&freeshipping=1&fs_ab=2&fuse_fs=&lang=en&location=Vietnam&price=3.97E%205&priceCompare=skuId%3A5180394996%3Bsource%3Alazada-search-voucher%3Bsn%3A0230bec5a85024148e0d6506ba1454fc%3BunionTrace%3A9c3b88a217307361401134524e%3BoriginPrice%3A397000%3BvoucherPrice%3A397000%3BdisplayPrice%3A397000%3BsinglePromotionId%3A-1%3BsingleToolCode%3AmockedSalePrice%3BvoucherPricePlugin%3A1%3BbuyerId%3A0%3Btimestamp%3A1730736140507&ratingscore=4.922063666300768&request_id=0230bec5a85024148e0d6506ba1454fc&review=1822&sale=9325&search=1&source=search&spm=a2o4n.searchlist.list.5&stock=1")

# %%
# Lấy các bình luận của khách hàng, bỏ qua các phản hồi của shop
content = driver.find_elements(By.CSS_SELECTOR, ".item-content .content:not(.seller-reply-wrapper .content)")
content_cmt = [elem.text for elem in content]
content_cmt
# Out:
# []

# %%
count = 1
content_cmt,date_cmt,star_cmt = [],[],[]
while True:
      try:
            print("Craw page " + str(count))
            count+=1
            
            content = driver.find_elements(By.CSS_SELECTOR, ".item-content .content:not(.seller-reply-wrapper .content)")
            content_cmt = [elem.text for elem in content] + content_cmt

            
            review_elements = driver.find_elements(By.CSS_SELECTOR, ".container-star.starCtn.left")
            for review in review_elements:
                  stars = review.find_elements(By.CSS_SELECTOR, "img.star")
                              
                  bright_stars = 0
                  for star in stars:
                        src = star.get_attribute("src")
                  
                        if "TB19ZvEgfDH8KJjy1XcXXcpdXXa" in src:
                              bright_stars += 1
                  star_cmt.append(bright_stars)
                  
              
            date = driver.find_elements(By.CSS_SELECTOR,".top .title " )
            date_cmt = [elem.text for elem in date] + date_cmt
            
            next = driver.find_element(By.XPATH, "/html/body/div[5]/div/div[10]/div[1]/div[2]/div/div/div/div[3]/div[2]/div/button[2]/i")
            next_cmt = next.click()
            sleep(10)
            
      
            # try :
            #       next_1 = driver.find_elements(By.CLASS_NAME,"baxia-dialog-close")
            #       next_1_cmt = next_1.click()
            #       sleep(15)

            # except ElementNotInteractableException:
            #       continue
                              
      except (ElementNotInteractableException, NoSuchElementException,ElementClickInterceptedException) as e :
            print("Lỗi ",e)
            break
# Out:
# Craw page 1
# Craw page 2
# Lỗi  Message: element click intercepted: Element <i class="next-icon next-icon-arrow-right next-icon-medium next-icon-last" data-spm-anchor-id="a2o4n.pdp_revamp.ratings_reviews.i1.450b6d20t5P2ff"></i> is not clickable at point (949, 615). Other element would receive the click: <div class="button-mod-box">...</div>
#   (Session info: chrome=130.0.6723.92)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7CCC93AF5+28005]
# 	(No symbol) [0x00007FF7CCBF83F0]
# 	(No symbol) [0x00007FF7CCA9580A]
# 	(No symbol) [0x00007FF7CCAED6CE]
# 	(No symbol) [0x00007FF7CCAEB16C]
# 	(No symbol) [0x00007FF7CCAE8628]
# 	(No symbol) [0x00007FF7CCAE785D]
# 	(No symbol) [0x00007FF7CCAD990E]
# 	(No symbol) [0x00007FF7CCB0BA3A]
# 	(No symbol) [0x00007FF7CCAD9246]
# 	(No symbol) [0x00007FF7CCB0BC50]
# 	(No symbol) [0x00007FF7CCB2B8B3]
# 	(No symbol) [0x00007FF7CCB0B7E3]
# 	(No symbol) [0x00007FF7CCAD75C8]
# 	(No symbol) [0x00007FF7CCAD8731]
# ...

# %%
content_cmt
# Out:
# ['',
#  '',
#  '',
#  'hàng ok lắm  ',
#  '',
#  '',
#  'Phù hợp cho cả sử dụng trong nhà và ngoài trời,  ',
#  'OK với tầm giá  ',
#  'hàng chất lượng cảm ơn shòp ',
#  '',
#  'tốt',
#  '',
#  '',
#  'congnghehoangnguyen.com 😍😍😍',
#  '',
#  '',
#  'Shop thân thiện giao đúng hàng ,giao hàng nhanh ,đủ số lượng ,hình ảnh minh hoạ nhận xu vì mình lười chụp.',
#  'chất lượng tốt ,đáng tin cậy ',
#  '',
#  'OK hình ảnh như quảng cáo chất lượng hình ảnh trong tầm tiền này là ok lắm còn bền hay không để thời gian trả lời',
#  'Chất lượng hình ảnh tuyệt vời,cài đặt dễ dàng ủng hộ shop',
#  'Hàng ok đợt trước thấy còn niêm phong còn đợt này thấy bóc niêm phong tung toé hy vọng sản phẩm không có lỗi gì',
#  '',
#  'Oki đây ',
#  'camera chất lượng hàng mới tin cho shop năm sao mọi nguoi nên mua shop này nhé chúc shop mua mai bán đắt nhé ',
#  '',
#  'Giá Cả: giá hợp lý\n Kết nối: tốt\n Độ phân giải: đẹp\n ',
# ...

# %%
df = pd.DataFrame(list(zip(content_cmt,star_cmt, date_cmt)), columns=['content_cmt','star_cmt','date_cmt'])

# Lưu DataFrame vào file CSV
df.to_csv("shop_Camera_Toan_Cau.csv",mode="a",header=False, index=False, encoding='utf-8')

print("Đã lưu bình luận vào file")
# Out:
# Đã lưu bình luận vào file

# %%
len(star_cmt)
# Out:
# 10
