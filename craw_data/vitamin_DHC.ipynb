# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException,ElementClickInterceptedException,StaleElementReferenceException
from selenium.webdriver.common.by import By
from time import sleep
import pandas as pd

# %%
#Thu_Duc_
driver = webdriver.Chrome()
driver.get("https://www.lazada.vn/products/vien-uong-bo-sung-vitamin-c-dhc-nhat-ban-goi-dung-60-ngay-i2278649930-s11020541067.html?c=&channelLpJumpArgs=&clickTrackInfo=query%253Avi%2525C3%2525AAn%252Bu%2525E1%2525BB%252591ng%252BVitamins%252BC%252BDHC%253Bnid%253A2278649930%253Bsrc%253ALazadaMainSrp%253Brn%253A2b86ad875c283e1d8a3b8868020cfe00%253Bregion%253Avn%253Bsku%253A2278649930_VNAMZ%253Bprice%253A76000%253Bclient%253Adesktop%253Bsupplier_id%253A200352048888%253Bbiz_source%253Ahttps%253A%252F%252Fwww.lazada.vn%252F%253Bslot%253A2%253Butlog_bucket_id%253A470687%253Basc_category_id%253A2375%253Bitem_id%253A2278649930%253Bsku_id%253A11020541067%253Bshop_id%253A3474931%253BtemplateInfo%253A107883_C_D_E%25231103_B%2523-1_A3%25231108_L%2523&freeshipping=1&fs_ab=2&fuse_fs=&lang=en&location=Vietnam&price=7.1E%204&priceCompare=skuId%3A11020541067%3Bsource%3Alazada-search-voucher%3Bsn%3A2b86ad875c283e1d8a3b8868020cfe00%3BunionTrace%3A9c3b88a217307845325527649e%3BoriginPrice%3A76000%3BvoucherPrice%3A71000%3BdisplayPrice%3A71000%3BsinglePromotionId%3A900000033874032%3BsingleToolCode%3AmillionSubsidy%3BvoucherPricePlugin%3A1%3BbuyerId%3A0%3Btimestamp%3A1730784532993%3BsearchDisctDet%3A%5B%7B%22discountValue%22%3A5000%2C%22toolCode%22%3A%22mockedMillionSubsidy%22%2C%22voucherId%22%3A900000033874032%7D%5D&ratingscore=4.986622073578595&request_id=2b86ad875c283e1d8a3b8868020cfe00&review=1311&sale=2215&search=1&source=search&spm=a2o4n.searchlist.list.2&stock=1")

# %%
#Cosin_store
driver = webdriver.Chrome()
driver.get("https://www.lazada.vn/products/vien-uong-dhc-vitamin-c-hard-capsule-tui-180-vien-90-ngay-60-vien-30-ngay-cua-nhat-ban-dung-tang-suc-de-khang-ho-tro-sang-da-cosin-store-i1317982954-s9599969801.html?c=&channelLpJumpArgs=&clickTrackInfo=query%253Avi%2525C3%2525AAn%252Bu%2525E1%2525BB%252591ng%252BVitamins%252BC%252BDHC%253Bnid%253A1317982954%253Bsrc%253ALazadaMainSrp%253Brn%253A2b86ad875c283e1d8a3b8868020cfe00%253Bregion%253Avn%253Bsku%253A1317982954_VNAMZ%253Bprice%253A85000%253Bclient%253Adesktop%253Bsupplier_id%253A200164314880%253Bbiz_source%253Ahttps%253A%252F%252Fwww.lazada.vn%252F%253Bslot%253A13%253Butlog_bucket_id%253A470687%253Basc_category_id%253A2375%253Bitem_id%253A1317982954%253Bsku_id%253A9599969801%253Bshop_id%253A1739849%253BtemplateInfo%253A107883_C_D_E%25231103_B_L%2523-1_A3%2523&freeshipping=1&fs_ab=2&fuse_fs=&lang=en&location=Vietnam&price=8.5E%204&priceCompare=skuId%3A9599969801%3Bsource%3Alazada-search-voucher%3Bsn%3A2b86ad875c283e1d8a3b8868020cfe00%3BunionTrace%3A9c3b88a217307845325527649e%3BoriginPrice%3A85000%3BvoucherPrice%3A85000%3BdisplayPrice%3A85000%3BsinglePromotionId%3A-1%3BsingleToolCode%3AmockedSalePrice%3BvoucherPricePlugin%3A1%3BbuyerId%3A0%3Btimestamp%3A1730784532993&ratingscore=4.975468975468975&request_id=2b86ad875c283e1d8a3b8868020cfe00&review=1386&sale=4938&search=1&source=search&spm=a2o4n.searchlist.list.13&stock=1")

# %%
#DHC
driver = webdriver.Chrome()
driver.get("https://www.lazada.vn/products/vien-uong-bo-sung-vitamin-c-ho-tro-sang-da-mo-tham-tang-cuong-de-khang-20-ngay-60-ngay-tpbvsk-dhc-vitamin-c-hard-capsule-i1701430266-s8844046769.html?c=&channelLpJumpArgs=&clickTrackInfo=query%253Avi%2525C3%2525AAn%252Bu%2525E1%2525BB%252591ng%252BVitamins%252BC%252BDHC%253Bnid%253A1701430266%253Bsrc%253ALazadaMainSrp%253Brn%253Acdae96c38e756c9a277010cecf92f733%253Bregion%253Avn%253Bsku%253A1701430266_VNAMZ%253Bprice%253A69000%253Bclient%253Adesktop%253Bsupplier_id%253A200173599534%253Bbiz_source%253Ahttps%253A%252F%252Fwww.lazada.vn%252F%253Bslot%253A15%253Butlog_bucket_id%253A470687%253Basc_category_id%253A2375%253Bitem_id%253A1701430266%253Bsku_id%253A8844046769%253Bshop_id%253A2597090%253BtemplateInfo%253A107883_C_D_E%2523-1_A3%25231103_B%25231108_L%2523&freeshipping=1&fs_ab=2&fuse_fs=&lang=en&location=Vietnam&price=6.9E%204&priceCompare=skuId%3A8844046769%3Bsource%3Alazada-search-voucher%3Bsn%3Acdae96c38e756c9a277010cecf92f733%3BunionTrace%3A9c3b88a017307849150092366e%3BoriginPrice%3A69000%3BvoucherPrice%3A69000%3BdisplayPrice%3A69000%3BsinglePromotionId%3A-1%3BsingleToolCode%3AmockedSalePrice%3BvoucherPricePlugin%3A1%3BbuyerId%3A0%3Btimestamp%3A1730784915369&ratingscore=4.971264367816092&request_id=cdae96c38e756c9a277010cecf92f733&review=5254&sale=13751&search=1&source=search&spm=a2o4n.searchlist.list.15&stock=1")

# %%
content = driver.find_elements(By.CSS_SELECTOR, ".item-content .content:not(.seller-reply-wrapper .content)")
content_cmt = [elem.text for elem in content]
content_cmt

# %%
count = 1
content_cmt,date_cmt,star_cmt = [],[],[]
while True:
      try:
            print("Craw page " + str(count))
            count+=1
            
            content = driver.find_elements(By.CSS_SELECTOR, ".item-content .content:not(.seller-reply-wrapper .content)")
            content_cmt = [elem.text for elem in content] + content_cmt

            
            review_elements = driver.find_elements(By.CSS_SELECTOR, ".container-star.starCtn.left")
            for review in review_elements:
                  stars = review.find_elements(By.CSS_SELECTOR, "img.star")
                              
                  bright_stars = 0
                  for star in stars:
                        src = star.get_attribute("src")
                  
                        if "TB19ZvEgfDH8KJjy1XcXXcpdXXa" in src:
                              bright_stars += 1
                  star_cmt.append(bright_stars)
                  
              
            date = driver.find_elements(By.CSS_SELECTOR,".top .title " )
            date_cmt = [elem.text for elem in date] + date_cmt
            
            next = driver.find_element(By.XPATH, "/html/body/div[5]/div/div[10]/div[1]/div[2]/div/div/div/div[3]/div[2]/div/button[2]/i")
            next_cmt = next.click()
            sleep(10)
            
      
            # try :
            #       next_1 = driver.find_elements(By.XPATH,"/html/body/div[9]/div[2]/div")
            #       next_1_cmt = next_1.click()
            #       sleep(15)   

            # except ElementNotInteractableException:
            #       continue
                         
      except (ElementNotInteractableException, NoSuchElementException,ElementClickInterceptedException) as e :
            print("Lỗi ",e)
            break
# Out:
# Craw page 1
# Craw page 2
# Craw page 3
# Craw page 4
# Craw page 5
# Craw page 6
# Craw page 7
# Craw page 8
# Craw page 9
# Craw page 10
# Craw page 11
# Craw page 12
# Craw page 13
# Craw page 14
# Craw page 15
# Craw page 16
# Craw page 17
# Craw page 18
# Craw page 19
# Craw page 20
# Craw page 21
# Craw page 22
# Craw page 23
# Craw page 24
# Craw page 25
# Craw page 26
# Craw page 27
# Craw page 28
# Craw page 29
# Lỗi  Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[5]/div/div[10]/div[1]/div[2]/div/div/div/div[3]/div[2]/div/button[2]/i"}
#   (Session info: chrome=130.0.6723.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7591F3B05+28005]
# 	(No symbol) [0x00007FF759158400]
# 	(No symbol) [0x00007FF758FF580A]
# 	(No symbol) [0x00007FF759045A3E]
# 	(No symbol) [0x00007FF759045D2C]
# ...

# %%
df = pd.DataFrame(list(zip(content_cmt,star_cmt, date_cmt)), columns=['content_cmt','star_cmt','date_cmt'])

# Lưu DataFrame vào file CSV
df.to_csv("shop_DHC.csv",mode="a",header=False, index=False, encoding='utf-8')

print("Đã lưu bình luận vào file")
# Out:
# Đã lưu bình luận vào file

# %%
len(date_cmt)
# Out:
# 610

# %%
content_cmt
# Out:
# ['đã nhận được hàng ok, hình nhận xu hình nhận xu hình nhận xu hình nhận xu  ',
#  'Tot dung san pham tot. Thoi han su dung dai date xa ship hang nhanh chong ',
#  'sp  tôt uy tin ',
#  'Chất lượng:lần đầu sử dụng nên chưa biết như thế nào, sẽ quay lại đánh giá lần mua sau \n Động cơ:\n Chính hãng:\n ',
#  'nhận đủ hàng đặt mua thankshop okkkkkkkkkk kkkkkkkkkk shop giao hàng nhanh chóng ozfgbcjhvuk ',
#  'Shop gói hàng cẩn thận, giao hàng nhanh, mua hàng của mall nên rất yên tâm về chất lượng………..',
#  'xài thấy hiệu quả ở chỗ ko bị thâm nám nhiều hơn..... ko có uống là sẽ tệ hơn..... mn nên mua nhe',
#  'dùng thử được vài ngày rồi nha, thấy cũng oke lắm á, mong là có hiệu quả nè, đóng gói sản phẩm rất kĩ càng nè.',
#  'viên uống vitamin C bổ sung sức đề kháng, kèm theo đó viên kẽm giúp làm mịn da. 2 viên này có vỏ bọc giống nhau, khác kích thước nên hơi dễ nhầm',
#  'Chất lượng:\n Động cơ:\n Chính hãng:\nMinh họa.\nDùng hàng ngày thấy ít bệnh vặt ',
# ...

# %%
date_cmt
# Out:
# ['05 thg 9 2020',
#  '13 thg 12 2022',
#  '30 thg 11 2021',
#  '06 thg 3 2021',
#  '21 thg 10 2019',
#  '21 thg 10 2019',
#  '13 thg 7 2023',
#  '08 thg 8 2023',
#  '04 thg 2 2020',
#  '09 thg 9 2022',
#  '30 thg 11 2021',
#  '26 thg 8 2022',
#  '05 thg 10 2021',
#  '23 thg 4 2022',
#  '05 thg 10 2021',
#  '17 thg 3 2023',
#  '04 thg 2 2020',
#  '05 thg 9 2020',
#  '15 thg 9 2021',
#  '22 thg 8 2021',
#  '02 thg 1 2020',
#  '16 thg 2 2024',
#  '02 thg 1 2020',
#  '11 thg 7 2023',
#  '20 thg 8 2020',
#  '08 thg 2 2023',
#  '15 thg 9 2021',
#  '22 thg 8 2021',
#  '21 thg 10 2019',
#  '18 thg 11 2020',
#  '14 thg 12 2021',
#  '20 thg 8 2020',
#  '04 thg 6 2023',
#  '26 thg 9 2020',
#  '07 thg 7 2023',
#  '06 thg 12 2022',
#  '14 thg 12 2021',
#  '26 thg 9 2020',
#  '05 thg 9 2020',
#  '20 thg 6 2023',
#  '05 thg 10 2021',
#  '21 thg 10 2019',
#  '06 thg 3 2021',
#  '19 thg 9 2021',
#  '27 thg 12 2022',
#  '20 thg 8 2020',
#  '17 thg 3 2024',
#  '22 thg 9 2022',
#  '05 thg 9 2020',
# ...
