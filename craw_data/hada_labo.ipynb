# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException,ElementClickInterceptedException,StaleElementReferenceException
from selenium.webdriver.common.by import By
from time import sleep
import pandas as pd

# %%
#Guardian page 202
driver = webdriver.Chrome()
driver.get('https://www.lazada.vn/products/kem-rua-mat-duong-am-hada-labo-advanced-nourish-hyaluronic-acid-cleanser-80gr-i872294328-s2491990197.html?c=&channelLpJumpArgs=&clickTrackInfo=query%253As%2525E1%2525BB%2525AFa%252Br%2525E1%2525BB%2525ADa%252Bm%2525E1%2525BA%2525B7t%252Bhada%252Blabo%253Bnid%253A872294328%253Bsrc%253ALazadaMainSrp%253Brn%253A2db38b8db7bbad0f746ecd3bfd97593e%253Bregion%253Avn%253Bsku%253A872294328_VNAMZ%253Bprice%253A70000%253Bclient%253Adesktop%253Bsupplier_id%253A200163552658%253Bbiz_source%253Ahttps%253A%252F%252Fwww.lazada.vn%252F%253Bslot%253A1%253Butlog_bucket_id%253A470687%253Basc_category_id%253A2289%253Bitem_id%253A872294328%253Bsku_id%253A2491990197%253Bshop_id%253A1630983%253BtemplateInfo%253A107883_C_D_E%25231103_B_L%2523-1_A3%2523&freeshipping=1&fs_ab=2&fuse_fs=&lang=en&location=Vietnam&price=7E%204&priceCompare=skuId%3A2491990197%3Bsource%3Alazada-search-voucher%3Bsn%3A2db38b8db7bbad0f746ecd3bfd97593e%3BunionTrace%3A9c3b88a117305623962671582e%3BoriginPrice%3A70000%3BvoucherPrice%3A70000%3BdisplayPrice%3A70000%3BsinglePromotionId%3A-1%3BsingleToolCode%3AmockedSalePrice%3BvoucherPricePlugin%3A1%3BbuyerId%3A0%3Btimestamp%3A1730562396687&ratingscore=4.948148148148148&request_id=2db38b8db7bbad0f746ecd3bfd97593e&review=2565&sale=14155&search=1&source=search&spm=a2o4n.searchlist.list.1&stock=1')

# %%
#KITY COSMETIC full 
driver = webdriver.Chrome()
driver.get("https://www.lazada.vn/products/kem-rua-mat-duong-am-toi-uu-hada-labo-advanced-nourish-hyaluronic-acid-cleanser-80g-i1714664935-s7636908263.html?c=&channelLpJumpArgs=&clickTrackInfo=query%253As%2525E1%2525BB%2525AFa%252Br%2525E1%2525BB%2525ADa%252Bm%2525E1%2525BA%2525B7t%252Bhada%252Blabo%253Bnid%253A1714664935%253Bsrc%253ALazadaMainSrp%253Brn%253A2db38b8db7bbad0f746ecd3bfd97593e%253Bregion%253Avn%253Bsku%253A1714664935_VNAMZ%253Bprice%253A66000%253Bclient%253Adesktop%253Bsupplier_id%253A1000071954%253Bbiz_source%253Ahttps%253A%252F%252Fwww.lazada.vn%252F%253Bslot%253A14%253Butlog_bucket_id%253A470687%253Basc_category_id%253A2289%253Bitem_id%253A1714664935%253Bsku_id%253A7636908263%253Bshop_id%253A329981%253BtemplateInfo%253A107883_C_D_E%25231103_B_L%2523-1_A3%2523&freeshipping=1&fs_ab=2&fuse_fs=&lang=en&location=Vietnam&price=6.6E%204&priceCompare=skuId%3A7636908263%3Bsource%3Alazada-search-voucher%3Bsn%3A2db38b8db7bbad0f746ecd3bfd97593e%3BunionTrace%3A9c3b88a117305623962671582e%3BoriginPrice%3A66000%3BvoucherPrice%3A66000%3BdisplayPrice%3A66000%3BsinglePromotionId%3A-1%3BsingleToolCode%3AmockedSalePrice%3BvoucherPricePlugin%3A1%3BbuyerId%3A0%3Btimestamp%3A1730562396687&ratingscore=4.962630792227205&request_id=2db38b8db7bbad0f746ecd3bfd97593e&review=669&sale=4856&search=1&source=search&spm=a2o4n.searchlist.list.14&stock=1")

# %%
#Hada Labo
driver = webdriver.Chrome()
driver.get("https://www.lazada.vn/products/sua-rua-mat-duong-am-toi-uu-hada-labo-advanced-nourish-cleanser-80g-i1463381499-s6068083445.html?c=&channelLpJumpArgs=&clickTrackInfo=query%253As%2525E1%2525BB%2525AFa%252Br%2525E1%2525BB%2525ADa%252Bm%2525E1%2525BA%2525B7t%252Bhada%252Blabo%253Bnid%253A1463381499%253Bsrc%253ALazadaMainSrp%253Brn%253A2db38b8db7bbad0f746ecd3bfd97593e%253Bregion%253Avn%253Bsku%253A1463381499_VNAMZ%253Bprice%253A75000%253Bclient%253Adesktop%253Bsupplier_id%253A200168688064%253Bbiz_source%253Ahttps%253A%252F%252Fwww.lazada.vn%252F%253Bslot%253A0%253Butlog_bucket_id%253A470687%253Basc_category_id%253A2289%253Bitem_id%253A1463381499%253Bsku_id%253A6068083445%253Bshop_id%253A2185360%253BtemplateInfo%253A107883_C_D_E%25231103_B_L%2523-1_A3%2523&freeshipping=1&fs_ab=2&fuse_fs=&lang=en&location=Vietnam&price=7.5E%204&priceCompare=skuId%3A6068083445%3Bsource%3Alazada-search-voucher%3Bsn%3A2db38b8db7bbad0f746ecd3bfd97593e%3BunionTrace%3A9c3b88a117305623962671582e%3BoriginPrice%3A75000%3BvoucherPrice%3A75000%3BdisplayPrice%3A75000%3BsinglePromotionId%3A-1%3BsingleToolCode%3AmockedSalePrice%3BvoucherPricePlugin%3A1%3BbuyerId%3A0%3Btimestamp%3A1730562396687&ratingscore=4.936184657162254&request_id=2db38b8db7bbad0f746ecd3bfd97593e&review=4419&sale=25349&search=1&source=search&spm=a2o4n.searchlist.list.0&stock=1")

# %%
count = 1
content_cmt,date_cmt,star_cmt = [],[],[]
while True:
      try:
            print("Craw page " + str(count))
            count+=1
            
            content = driver.find_elements(By.CSS_SELECTOR, ".item-content .content")
            content_cmt = [elem.text for elem in content if "Hada Labo " not in elem.text ] + content_cmt
            
            
            review_elements = driver.find_elements(By.CSS_SELECTOR, ".container-star.starCtn.left")
            for review in review_elements:
                  stars = review.find_elements(By.CSS_SELECTOR, "img.star")
                              
                  bright_stars = 0
                  for star in stars:
                        src = star.get_attribute("src")
                  
                        if "TB19ZvEgfDH8KJjy1XcXXcpdXXa" in src:
                              bright_stars += 1
                  star_cmt.append(bright_stars)
                  
              
            date = driver.find_elements(By.CSS_SELECTOR,".top .title " )
            date_cmt = [elem.text for elem in date] + date_cmt
            
            next = driver.find_element(By.XPATH, "/html/body/div[5]/div/div[10]/div[1]/div[2]/div/div/div/div[3]/div[2]/div/button[2]/i")
            next_cmt = next.click()
            sleep(10)
            
      
            # try :
            #       next_1 = driver.find_elements(By.CLASS_NAME,"baxia-dialog-close")
            #       next_1_cmt = next_1.click()
            #       sleep(15) #lỗi phát hiện spam(có thể do click nhiều lần hoặc nghi ngờ root)

            # except ElementNotInteractableException:
            #       continue
                              
      except (ElementNotInteractableException, NoSuchElementException,ElementClickInterceptedException) as e :
            print("Lỗi ",e)
            break
# Out:
# Craw page 1
# Craw page 2
# Craw page 3
# Craw page 4
# Craw page 5
# Craw page 6
# Craw page 7
# Craw page 8
# Craw page 9
# Craw page 10
# Craw page 11
# Craw page 12
# Craw page 13
# Craw page 14
# Craw page 15
# Craw page 16
# Craw page 17
# Craw page 18
# Craw page 19
# Craw page 20
# Craw page 21
# Craw page 22
# Craw page 23
# Craw page 24
# Craw page 25
# Craw page 26
# Craw page 27
# Craw page 28
# Craw page 29
# Craw page 30
# Craw page 31
# Craw page 32
# Craw page 33
# Craw page 34
# Craw page 35
# Craw page 36
# Craw page 37
# Craw page 38
# Craw page 39
# Craw page 40
# Craw page 41
# Craw page 42
# Craw page 43
# Craw page 44
# Craw page 45
# Craw page 46
# Craw page 47
# Craw page 48
# Craw page 49
# Craw page 50
# Craw page 51
# Craw page 52
# Craw page 53
# Craw page 54
# Craw page 55
# Craw page 56
# Craw page 57
# Craw page 58
# Craw page 59
# Craw page 60
# Craw page 61
# Craw page 62
# Craw page 63
# Craw page 64
# Craw page 65
# Craw page 66
# Craw page 67
# ...

# %%
date_cmt
# Out:
# ['05 thg 1 2023',
#  '13 thg 12 2023',
#  '05 thg 8 2024',
#  '13 thg 7 2024',
#  '17 thg 1 2022',
#  '24 thg 8 2022',
#  '16 thg 9 2023',
#  '11 thg 6 2024',
#  '28 thg 9 2023',
#  '19 thg 12 2022',
#  '27 thg 2 2022',
#  '16 thg 7 2022',
#  '06 thg 1 2023',
#  '13 thg 12 2023',
#  '01 thg 12 2022',
#  '09 thg 6 2024',
#  '15 thg 12 2023',
#  '26 thg 7 2024',
#  '26 thg 12 2022',
#  '07 thg 6 2024',
#  '06 thg 4 2024',
#  '11 thg 6 2022',
#  '03 thg 8 2022',
#  '30 thg 12 2023',
#  '05 thg 3 2024',
#  '06 thg 4 2024',
#  '11 thg 6 2022',
#  '03 thg 8 2022',
#  '30 thg 12 2023',
#  '05 thg 3 2024',
#  '2 tuần trước',
#  '16 thg 7 2022',
#  '24 thg 5 2024',
#  '29 thg 1 2024',
#  '29 thg 7 2024',
#  '18 thg 10 2023',
#  '24 thg 10 2023',
#  '29 thg 3 2024',
#  '13 thg 2 2022',
#  '25 thg 4 2024',
#  '13 thg 6 2022',
#  '10 thg 7 2024',
#  '28 thg 7 2022',
#  '28 thg 5 2024',
#  '12 thg 8 2024',
#  '06 thg 4 2022',
#  '07 thg 6 2024',
#  '08 thg 6 2024',
#  '29 thg 3 2022',
# ...

# %%
with open("comments.csv", "w", encoding="utf-8") as file:
    file.write("content_cmt\n")  # Ghi tiêu đề của cột vào file CSV

    # Ghi từng bình luận vào file, mỗi bình luận trên một dòng
    for comment in content_cmt:
        file.write(f"{comment}\n")

print("Đã lưu bình luận vào file comments.csv")

# %%
df = pd.DataFrame(list(zip(content_cmt,star_cmt, date_cmt)), columns=['content_cmt','star_cmt','date_cmt'])

# Lưu DataFrame vào file CSV
df.to_csv("shop_HadaLabo.csv",mode="a",header=False, index=False, encoding='utf-8')

print("Đã lưu bình luận vào file")
# Out:
# Đã lưu bình luận vào file
